# %% [markdown]
# ## **1. Introduction to Pandas**
#
# #### **Task 1.1: Importing Pandas**
# #### Import the Pandas library and assign it the conventional alias `pd`.

# %%
import pandas as pd

# %% [markdown]
# #### **Task 1.2: Understanding Pandas Data Structures**
# #### Briefly explain in a comment what the two primary data structures in Pandas are and what they represent.

# %%
print("The two primary data structures in Pandas are:\n")
print("1. Series: A 1-dimensional labeled array capable of holding any data type (e.g., integers, strings, floats). It represents a single column or row.")
print("2. DataFrame: A 2-dimensional labeled data structure with columns of potentially different types. It represents an entire table or spreadsheet.")
# Out:
# The two primary data structures in Pandas are:
#
# 1. Series: A 1-dimensional labeled array capable of holding any data type (e.g., integers, strings, floats). It represents a single column or row.
# 2. DataFrame: A 2-dimensional labeled data structure with columns of potentially different types. It represents an entire table or spreadsheet.

# %% [markdown]
# ## **2. Series**
#
# #### **Task 2.1: Creating a Series from a List**
# #### Create a Pandas Series named `fruits` from the following Python list: `['apple', 'banana', 'cherry', 'date']`.
# #### Print the Series.

# %%
fruits = ['apple', 'banana', 'cherry', 'date']

fruits_series = pd.Series(fruits)

print(fruits_series)
# Out:
# 0     apple
# 1    banana
# 2    cherry
# 3      date
# dtype: object

# %% [markdown]
# #### **Task 2.2: Creating a Series with Custom Indices**
# #### Create a Pandas Series named `colors` from the following Python list: `['red', 'green', 'blue']`.
# #### Assign the indices as `['color1', 'color2', 'color3']`.
# #### Print the Series.

# %%
colors = pd.Series(['red', 'green', 'blue'],index = ['color1', 'color2', 'color3'])

print(colors)
# Out:
# color1      red
# color2    green
# color3     blue
# dtype: object

# %% [markdown]
# #### **Task 2.3: Accessing Elements in a Series**
# #### Using the `fruits` Series, access and print the element at index 1.
# #### Using the `colors` Series, access and print the element with the index 'color2'.

# %%
print("fruits series index element 1 position : ",fruits_series[1])

print("color series index element 'color 2' position : ",colors['color2'])
# Out:
# fruits series index element 1 position :  banana
# color series index element 'color 2' position :  green

# %% [markdown]
# ## **3. DataFrame**
#
# #### **Task 3.1: Creating a DataFrame from a Dictionary of Lists**
# #### Create a Pandas DataFrame named `student_data` from the following Python dictionary:
# #### {
# ####  'name': ['Alice', 'Bob', 'Charlie'],
# ####  'age': [20, 21, 19],
# ####  'major': ['CS', 'Engineering', 'Math']
# #### }
# #### Print the DataFrame.

# %%
student_data = pd.DataFrame({
    'name' : ['Alice', 'Bob', 'Charlie'],
    'age' : [20, 21, 19],
    'major' : ['CS', 'Engineering', 'Math']
    })

print(student_data)
# Out:
#       name  age        major
# 0    Alice   20           CS
# 1      Bob   21  Engineering
# 2  Charlie   19         Math

# %% [markdown]
# #### **Task 3.2: Creating a DataFrame from a List of Dictionaries**
# #### Create a Pandas DataFrame named `employee_data` from the following Python list of dictionaries:
# #### [{'name': 'David', 'salary': 50000, 'department': 'Sales'},
# ####  {'name': 'Eve', 'salary': 60000, 'department': 'Marketing'},
# ####  {'name': 'Frank', 'salary': 55000, 'department': 'Sales'}]
# #### Print the DataFrame.

# %%
employee_data = pd.DataFrame({
    'name' : ['David', 'Eve', 'Frank'],
    'salary' : ['50000', '60000', '55000'],
    'department' : ['Sales', 'Marketing', 'Sales']
})

print(employee_data)
# Out:
#     name salary department
# 0  David  50000      Sales
# 1    Eve  60000  Marketing
# 2  Frank  55000      Sales

# %% [markdown]
# #### **Task 3.3: Creating a DataFrame from a NumPy Array**
# #### Create a NumPy array `data_array` with shape (3, 2) containing random integers between 1 and 10.
# #### Create a Pandas DataFrame named `random_df` from this NumPy array with column names 'Column A' and 'Column B'.
# #### Print the DataFrame.

# %%
import numpy as np
import random

data_array = np.random.randint(1, 11, size=(3, 2))

random_df = pd.DataFrame(data_array, columns=['Column A', 'Column B'])

print(random_df)
# Out:
#    Column A  Column B
# 0         4         5
# 1         6         6
# 2         9        10

# %% [markdown]
# ## **4. Exploring Data (Series and DataFrame)**
#
# #### **Task 4.1: Exploring a Series**
# #### Using the `fruits` Series, find and print:
# #### - The number of elements in the Series.
# #### - The unique values in the Series.
# #### - The count of each unique value in the Series.

# %%
print("Original Series :\n",fruits_series)

print("Fruits Number of Elements :\n",fruits_series.size)
print("Fruits unique values in Series :\n",fruits_series.unique())
print("Fruits count of each unique value in Series :\n",fruits_series.value_counts())
# Out:
# Original Series :
#  0     apple
# 1    banana
# 2    cherry
# 3      date
# dtype: object
# Fruits Number of Elements :
#  4
# Fruits unique values in Series :
#  ['apple' 'banana' 'cherry' 'date']
# Fruits count of each unique value in Series :
#  apple     1
# banana    1
# cherry    1
# date      1
# Name: count, dtype: int64

# %% [markdown]
# #### **Task 4.2: Exploring a DataFrame**
# #### Using the `student_data` DataFrame, find and print:
# #### - The first 2 rows of the DataFrame.
# #### - The last row of the DataFrame.
# #### - The index of the DataFrame.
# #### - The column names of the DataFrame.
# #### - A concise summary of the DataFrame (including data types and non-null values).

# %%
print("Original DataFrame :\n",student_data)

print("First 2 rows of DataFrame :\n",student_data.head(2))
print("Last row of DataFrame :\n",student_data.tail(1))
print("DataFrame Index :\n",student_data.index)
print("DataFrame Column Names :\n",student_data.columns)
print("DataFrame Summary of DataFrame :\n",student_data.info())
# Out:
# Original DataFrame :
#        name  age        major
# 0    Alice   20           CS
# 1      Bob   21  Engineering
# 2  Charlie   19         Math
# First 2 rows of DataFrame :
#      name  age        major
# 0  Alice   20           CS
# 1    Bob   21  Engineering
# Last row of DataFrame :
#        name  age major
# 2  Charlie   19  Math
# DataFrame Index :
#  RangeIndex(start=0, stop=3, step=1)
# DataFrame Column Names :
#  Index(['name', 'age', 'major'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   age     3 non-null      int64
#  2   major   3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes
# DataFrame Summary of DataFrame :
#  None

# %% [markdown]
# #### **Task 4.3: Selecting Columns and Rows**
# #### Using the `employee_data` DataFrame:
# #### - Select and print only the 'name' column.
# #### - Select and print the row at index 1.
# #### - Select and print the 'name' and 'salary' columns.
# #### - Select and print the first two rows and the 'name' and 'department' columns.

# %%
print("Original DataFrame :\n",employee_data)

print("Select and print only name colume :\n",employee_data.name)
print("Select and print row index 1 :\n",employee_data.iloc[1])
print("Select and print name and salary columns :\n",employee_data[['name', 'salary']])
print("Select and print first two rows name and department :\n", employee_data.head(2)[['name', 'department']])
# Out:
# Original DataFrame :
#      name salary department
# 0  David  50000      Sales
# 1    Eve  60000  Marketing
# 2  Frank  55000      Sales
# Select and print only name colume :
#  0    David
# 1      Eve
# 2    Frank
# Name: name, dtype: object
# Select and print row index 1 :
#  name                Eve
# salary            60000
# department    Marketing
# Name: 1, dtype: object
# Select and print name and salary columns :
#      name salary
# 0  David  50000
# 1    Eve  60000
# 2  Frank  55000
# Select and print first two rows name and department :
#      name department
# 0  David      Sales
# 1    Eve  Marketing

# %% [markdown]
# ## **5. Operations on DataFrames**
#
# #### **Task 5.1: Adding a New Column**
# #### Add a new column named 'city' to the `student_data` DataFrame with the values: `['New York', 'London', 'Paris']`.
# #### Print the updated DataFrame.

# %%
print("Original DataFrame :\n",student_data)

student_data['city'] = ['New York', 'London', 'Paris']

print("Updated DataFrame :\n",student_data)
# Out:
# Original DataFrame :
#        name  age        major
# 0    Alice   20           CS
# 1      Bob   21  Engineering
# 2  Charlie   19         Math
# Updated DataFrame :
#        name  age        major      city
# 0    Alice   20           CS  New York
# 1      Bob   21  Engineering    London
# 2  Charlie   19         Math     Paris

# %% [markdown]
# #### **Task 5.2: Removing a Column**
# #### Remove the 'city' column from the `student_data` DataFrame.
# #### Print the DataFrame after removal.

# %%
print("Original DataFrame :\n", student_data)

student_data.drop('city', axis = 1, inplace = True)

print("Updated DataFrame :\n", student_data)
# Out:
# Original DataFrame :
#        name  age        major      city
# 0    Alice   20           CS  New York
# 1      Bob   21  Engineering    London
# 2  Charlie   19         Math     Paris
# Updated DataFrame :
#        name  age        major
# 0    Alice   20           CS
# 1      Bob   21  Engineering
# 2  Charlie   19         Math

# %% [markdown]
# #### **Task 5.3: Filtering Rows Based on a Condition**
# #### Using the `employee_data` DataFrame, filter and print the rows where the 'department' is 'Sales'.

# %%
print("Original DataFrame :\n",employee_data)

print("Filtered DataFrame :\n",employee_data[employee_data['department'] == 'Sales'])
# Out:
# Original DataFrame :
#      name salary department
# 0  David  50000      Sales
# 1    Eve  60000  Marketing
# 2  Frank  55000      Sales
# Filtered DataFrame :
#      name salary department
# 0  David  50000      Sales
# 2  Frank  55000      Sales

# %% [markdown]
# #### **Task 5.4: Sorting a DataFrame**
# #### Sort the `employee_data` DataFrame by the 'salary' column in descending order.
# #### Print the sorted DataFrame.

# %%
print("Original DataFrame :\n",employee_data)

print("Sorted(descending) DataFrame as Salary wise :\n", employee_data.sort_values(by='salary' , ascending=False))
# Out:
# Original DataFrame :
#      name salary department
# 0  David  50000      Sales
# 1    Eve  60000  Marketing
# 2  Frank  55000      Sales
# Sorted DataFrame as Salary wise :
#      name salary department
# 1    Eve  60000  Marketing
# 2  Frank  55000      Sales
# 0  David  50000      Sales

# %% [markdown]
# #### **Task 5.5: Basic Aggregation**
# #### Using the `employee_data` DataFrame, calculate and print the average salary of all employees.

# %%
print("Original DataFrame :\n",employee_data)

employee_data['salary'] = employee_data['salary'].astype(int)
print("Average salary of all employees :\n",employee_data['salary'].mean())
# Out:
# Original DataFrame :
#      name  salary department
# 0  David   50000      Sales
# 1    Eve   60000  Marketing
# 2  Frank   55000      Sales
# Average salary of all employees :
#  55000.0
