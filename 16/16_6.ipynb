# %% [markdown]
# ### **Summarize, Visualize, Merge and Join Data**
#
# ##### **Task 1: Sorting and Filtering Data**
# ##### 1.1 Load a dataset (e.g., Titanic or any CSV) into a DataFrame.
# ##### 1.2 Sort the dataset by a numerical column (e.g., Age, Fare) in descending order.
# ##### 1.3 Filter rows where a certain condition is met (e.g., Age > 30).

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({
    "Name" : ["Alice", "Bob", "Charlie", "David"],
    "Age" : [21, 20, 25, 22],
    "Fare" : [23000, 21000, 18000, 13000],
    "City" : ["New York", "Sun Francisco", "Paris", "London"]
})

data.to_csv("data_summarize.csv",index=False)

data = pd.read_csv("data_summarize.csv")

print("Age descending Order : ")

data = data.sort_values('Age', ascending=False)

print(data)

print("Fare descending Order : ")

data = data.sort_values('Fare', ascending=False)

print(data)
# Out:
# Age descending Order :
#       Name  Age   Fare           City
# 2  Charlie   25  18000          Paris
# 3    David   22  13000         London
# 0    Alice   21  23000       New York
# 1      Bob   20  21000  Sun Francisco
# Fare descending Order :
#       Name  Age   Fare           City
# 0    Alice   21  23000       New York
# 1      Bob   20  21000  Sun Francisco
# 2  Charlie   25  18000          Paris
# 3    David   22  13000         London

# %% [markdown]
# ##### **Task 2: Aggregation and Grouping**
# ##### 2.1 Group the dataset by a categorical column (e.g., Gender, Class).
# ##### 2.2 Calculate aggregate statistics (mean, sum, count) for each group.
# ##### 2.3 Display the group with the highest average value of a selected column.

# %% [markdown]
# ##### **Task 3: Data Visualization**
# ##### 3.1 Create a bar chart to visualize the total counts for each group from Task 2.
# ##### 3.2 Create a pie chart showing the proportion of a categorical variable (e.g., Embarked port).
# ##### 3.3 Create a scatter plot for two numerical columns (e.g., Age vs Fare).

# %% [markdown]
# ##### **Task 4: Merging DataFrames**
# ##### 4.1 Create two small DataFrames manually:
# #####     - One with Employee ID and Name
# #####     - One with Employee ID and Salary
# ##### 4.2 Merge the two DataFrames using inner join.
# ##### 4.3 Merge the same DataFrames using outer join and observe the difference.

# %% [markdown]
# ##### **Task 5: Joining DataFrames**
# ##### 5.1 Create two DataFrames manually:
# #####     - One with Student ID and their Grades
# #####     - One with Student ID and their Activities
# ##### 5.2 Join them using left join.
# ##### 5.3 Join them using right join.

# %% [markdown]
# ##### **Task 6: Complex Merging**
# ##### 6.1 Load two datasets with common columns (e.g., Orders and Customers).
# ##### 6.2 Merge them to get Customer details alongside their Orders.
# ##### 6.3 Filter the merged dataset to show only high-value customers (TotalOrderValue > 1000).

# %% [markdown]
# ##### **Task 7: Advanced Aggregation**
# ##### 7.1 Group the merged dataset by a date field (e.g., Order Date by Month).
# ##### 7.2 Calculate monthly revenue.
# ##### 7.3 Plot a line chart to show revenue trends over months.

# %% [markdown]
# ##### **Task 8: Challenge Task**
# ##### 8.1 Create three small datasets: Products, Sales, and Returns.
# ##### 8.2 Merge them logically.
# ##### 8.3 Create a final report showing:
# #####     - Total Sales
# #####     - Total Returns
# #####     - Net Sales (Total Sales - Total Returns)
# ##### 8.4 Visualize the net sales per product using a bar chart.
